# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

fig2, ax2 = plt.subplots(1, 2, figsize = (10,10))

fig2.suptitle('Unknown 2', fontsize = 25)

ax2[0].plot(x,y, color = 'red', label = '(x,y)')
ax2[1].plot(x,z, label = '(x,z)')

fig2.legend()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
#Create figure and set title
fig, ax = plt.subplots(figsize = (10,10))
ax.set_title('Unknown', fontsize = 25)

#Plot (x,y) & (x,z)
ax.plot(x, y, label = '(x,y)', c='red')
ax.plot(x, z, label = '(x,z)', c='blue')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
#ALREADY DONE

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
import math

set_xscale = x ** 2
set_yscale = np.e**x

# %%
#Create figure and set title
fig3, ax3 = plt.subplots(figsize = (10,5))
fig4, ax4 = plt.subplots(figsize = (10,5))

ax3.set_title('Normal Scale', fontsize = 25)
ax4.set_title('Logarithmic Scale', fontsize = 25)

#Plot (x,y) & (x,z)
ax3.plot(set_xscale, label = 'Normal Scale', c='red')
ax4.plot(np.e**x, label = 'Logarithmic scale', c='blue')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv("Datasets_as_CSV/Fitbit2.csv")
titanic = pd.read_csv("Datasets_as_CSV/titanic.csv")

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
monthly_steps = fitbit.groupby(["Months"])["Steps"].median().reset_index()
steps
# MEDIAN STEPS BY WORK_OR_WEEKEND
week_type_steps = fitbit.groupby(["Work_or_Weekend"])["Steps"].median().reset_index()
week_type_steps
# Out:
#    Work_or_Weekend    Steps
# 0                0   9998.0
# 1                1  10445.5

# %%
fig5, axes5 = plt.subplots(1,2, figsize = (12,4))

#monthly steps
sns.barplot(data = monthly_steps, x = 'Steps', y = 'Months', ax = axes5[0])
axes5[0].set_title('Monthly', fontsize = 20)

#work or weekend
sns.barplot(data = week_type_steps, x = 'Work_or_Weekend', y = 'Steps', ax = axes5[1])
axes5[1].set_title('Week v. Weekend', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Week v. Weekend')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
columns = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']
data = fitbit.groupby(columns)["Steps"].median().reset_index()

x_col = "Steps"
y_columns = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for y_col in y_columns:
    figure = plt.figure
    ax = plt.gca()
    ax.scatter(data[x_col], data[y_col])
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_col)
    ax.set_title("{} vs {}".format(x_col, y_col))
    
    plt.legend()
    plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numerical_values = titanic.select_dtypes(int)

# %%
# CATEGORICAL VARIABLES
categorical_values = titanic.select_dtypes(float)

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use("classic")
fig6, axes6 = plt.subplots(figsize = (12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic.hist(column='Age')
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
#plot histogram
#parameter that sets number of boxes/bars
titanic.hist(column='Age', bins=10)
titanic.hist(column='Age', bins=20)
titanic.hist(column='Age', bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# The higher the bin size, means the plot has more detail.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.catplot(data = titanic, y = titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

#CREATE
gender = titanic['Gender'].value_counts()
x = gender.index
y = gender

#PLOT
fig10, ax10 = plt.subplots(figsize=(6,6))
ax10.bar(x,y, color=("paleturquoise","pink"))
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
#Sets color palette for any graph plotted: Red, Yellow, Green
sns.set_palette('BuPu')
#Dictionary, when type yes label, assign C5 color. when no, assign C0 color. 
palette_alive = {"female": "C5", "male": "C0"}

#CREATE
gender = titanic['Gender'].value_counts()
x = gender.index
y = gender

#PLOT

fig10, ax10 = plt.subplots(1, 2, figsize=(6,6))

#male
sns.barplot(data = titanic, x = gender.index, y = gender, ax = ax10[0], palette = palette_alive)
ax10[0].set_title('Males', fontsize = 20)

#female
sns.barplot(data = titanic, x = gender.index, y = gender, ax = ax10[1], palette = palette_alive)

ax10[1].set_title('Females', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Females')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
#CREATE
pclass = titanic['Pclass'].value_counts()
x = pclass.index
y = pclass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f0e32a659ed0> in <module>
#       1 #CREATE
# ----> 2 pclass = titanic['Pclass'].value_counts()
#       3 x = pclass.index
#       4 y = pclass
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #COME BACK TO THIS, LABEL COLUMNS

# %%
#PLOT
fig11, ax11 = plt.subplots(figsize=(6,6))
ax11.bar(x,y, color=("pink", "blue", "purple"))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
x_age = titanic["Age"].describe()
y_age = titanic["Age"].describe().index

sns.barplot(x = x_age, y = y_age)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.distplot(titanic["Age"])
# Out:
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

# create first figure and ax
fig, ax = plt.subplots(figsize = (5,5))

# we add a title to the figure or the ax
ax.set_title('Fare in Comparison to Age', fontsize = 25)

#Set x and y
x = titanic["Age"]
y = titanic["Fare"]

# we plot the different lines
ax.scatter(x, y, c='red')

# we add the legend ##for the label added 
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# Method 2 - seaborn
sns.regplot(x = titanic["Age"], y = titanic["Fare"], data = titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.catplot(data = titanic, x = 'Pclass', y = 'Age', kind = 'strip')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
FG = sns.catplot(data = titanic, x = 'Gender', y = 'Age', kind = 'strip', palette = palette_alive)
